# %%
# !pip3 install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.0/887.0 kB 14.9 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !yolo train model=yolov5s.yaml data=/kaggle/input/sku110k-annotations/data_kaggle.yaml
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo predict model=/kaggle/working/runs/detect/train2/weights/best.pt source=/kaggle/input/sku110k-annotations/SKU110K_fixed/images/train/train_10.jpg
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.14 torch-2.4.0 CUDA:0 (Tesla T4, 15095MiB)
# YOLOv5s summary (fused): 193 layers, 9,111,923 parameters, 0 gradients, 23.8 GFLOPs
#
# image 1/1 /kaggle/input/sku110k-annotations/SKU110K_fixed/images/train/train_10.jpg: 640x480 148 objects, 42.0ms
# Speed: 3.3ms preprocess, 42.0ms inference, 162.7ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo export model=/kaggle/working/runs/detect/train2/weights/best.pt format=torchscript
# Out:
# Ultralytics 8.3.32 🚀 Python-3.10.14 torch-2.4.0 CPU (Intel Xeon 2.00GHz)
# YOLOv5s summary (fused): 193 layers, 9,111,923 parameters, 0 gradients, 23.8 GFLOPs
#
# PyTorch: starting from '/kaggle/working/runs/detect/train2/weights/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (35.1 MB)
#
# TorchScript: starting export with torch 2.4.0...
# TorchScript: export success ✅ 3.1s, saved as '/kaggle/working/runs/detect/train2/weights/best.torchscript' (35.2 MB)
#
# Export complete (5.4s)
# Results saved to /kaggle/working/runs/detect/train2/weights
# Predict:         yolo predict task=detect model=/kaggle/working/runs/detect/train2/weights/best.torchscript imgsz=640
# Validate:        yolo val task=detect model=/kaggle/working/runs/detect/train2/weights/best.torchscript imgsz=640 data=/kaggle/input/sku110k-annotations/data_kaggle.yaml
# Visualize:       https://netron.app
# 💡 Learn more at https://docs.ultralytics.com/modes/export

# %%
from IPython.display import Image
Image(filename='/kaggle/working/runs/detect/predict/train_10.jpg')
